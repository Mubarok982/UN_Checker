# %% [markdown]
# <a href="https://colab.research.google.com/github/Mubarok982/UN_Checker/blob/main/unfollowchecker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup

# Fungsi ekstraksi username dari HTML
def extract_usernames_from_html(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        soup = BeautifulSoup(f, "html.parser")
        links = soup.find_all("a", href=True)
        usernames = [link["href"].replace("https://www.instagram.com/", "").strip("/") for link in links]
        return set(usernames)

# Ganti path ini sesuai file kamu
followers = extract_usernames_from_html("followers_1.html")
following = extract_usernames_from_html("following.html")

# Akun yang tidak follow balik
not_following_back = sorted(following - followers)

# Tampilkan tabel
print("| No | Username | Link |")
print("|----|----------|------|")
for i, username in enumerate(not_following_back, 1):
    print(f"| {i} | {username} | https://instagram.com/{username} |")

print(f"\nTotal akun yang tidak follow balik: {len(not_following_back)}")
# Out:
# | No | Username | Link |
# |----|----------|------|
# | 1 | 1001ptp_ungaran | https://instagram.com/1001ptp_ungaran |
# | 2 | 3zaardiyansah | https://instagram.com/3zaardiyansah |
# | 3 | ___cyclops_mge | https://instagram.com/___cyclops_mge |
# | 4 | _anastasyasaban_ | https://instagram.com/_anastasyasaban_ |
# | 5 | _eerichads | https://instagram.com/_eerichads |
# | 6 | _faniaaaa06 | https://instagram.com/_faniaaaa06 |
# | 7 | _flloraadanurr_ | https://instagram.com/_flloraadanurr_ |
# | 8 | _flolyaa | https://instagram.com/_flolyaa |
# | 9 | _jeanee09 | https://instagram.com/_jeanee09 |
# | 10 | _luqmanamrdn | https://instagram.com/_luqmanamrdn |
# | 11 | _ralita | https://instagram.com/_ralita |
# | 12 | _septiiww | https://instagram.com/_septiiww |
# | 13 | _wondanak22 | https://instagram.com/_wondanak22 |
# | 14 | aalamirullah | https://instagram.com/aalamirullah |
# | 15 | actventure_x | https://instagram.com/actventure_x |
# ...
